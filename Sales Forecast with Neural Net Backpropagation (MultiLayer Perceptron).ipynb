# %% [markdown]
# **    Id** - an Id that represents a (Store, Date) duple within the test set
#
# **    Store** - a unique Id for each store
#
# **    Sales** - the turnover for any given day (this is what you are predicting)
#
# **    Customers** - the number of customers on a given day
#
# **    Open** - an indicator for whether the store was open: 0 = closed, 1 = open
#
# **    StateHoliday** - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays.
#     Note    that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday,
#     c =   Christmas, 0 = None
#
# **    SchoolHoliday** - indicates if the (Store, Date) was affected by the closure of public schools
#
# **    StoreType** - differentiates between 4 different store models: a, b, c, d
#
# **    Assortment** - describes an assortment level: a = basic, b = extra, c = extended
#
# **    CompetitionDistance** - distance in meters to the nearest competitor store
#
# **    CompetitionOpenSince[Month/Year]** - gives the approximate year and month of the time the nearest competitor was opened
#
# **    Promo** - indicates whether a store is running a promo on that day
#
# **    Promo2** - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating,
#      1 = store is participating
#
# **    Promo2Since[Year/Week]** - describes the year and calendar week when the store started participating in Promo2
#
# **    PromoInterval**-describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew.
#     E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
import bs4

# %%
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Handle table like data and matrices
import numpy as np
import pandas as pd
import math

# Modelling Algorithm
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Modelling Helpers
from sklearn.preprocessing import Imputer, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# Visualization Configuration
# %matplotlib inline
mpl.style.use("ggplot")
sns.set_style("white")
plt.rcParams["figure.figsize"] = 12, 8

# %%
# Read the file
df = pd.read_csv("rossmann.csv")
store = pd.read_csv("store.csv")
test = pd.read_csv("test.csv")

# check the first 5 rows
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
sns.barplot(x='Promo', y='Sales', data=df)

# %%
sns.factorplot(x='DayOfWeek', y='Sales', data=df, hue='Promo', size=10)

# %%
plt.rcParams['figure.figsize'] = (12,10)
sns.boxplot(x='DayOfWeek', y='Sales', data=df, hue='Promo')

# %% [markdown]
# Based on the visuals above, the first thing that jumps out here is the company dosen't run any promotiions
# on the weekends and in terms of comparison promotion has huge effect on sales on monday and very lesss on friday

# %%
sns.factorplot(x='DayOfWeek', y='Customers', hue='Promo', data=df, size=10)

# %%
df.Date.unique()

# The data is from 1 jan 2013 to 7 jul 2015 about 2.5years of data that AMAZINGS
# Out:
# array(['2015-07-31', '2015-07-30', '2015-07-29', '2015-07-28',
#        '2015-07-27', '2015-07-26', '2015-07-25', '2015-07-24',
#        '2015-07-23', '2015-07-22', '2015-07-21', '2015-07-20',
#        '2015-07-19', '2015-07-18', '2015-07-17', '2015-07-16',
#        '2015-07-15', '2015-07-14', '2015-07-13', '2015-07-12',
#        '2015-07-11', '2015-07-10', '2015-07-09', '2015-07-08',
#        '2015-07-07', '2015-07-06', '2015-07-05', '2015-07-04',
#        '2015-07-03', '2015-07-02', '2015-07-01', '2015-06-30',
#        '2015-06-29', '2015-06-28', '2015-06-27', '2015-06-26',
#        '2015-06-25', '2015-06-24', '2015-06-23', '2015-06-22',
#        '2015-06-21', '2015-06-20', '2015-06-19', '2015-06-18',
#        '2015-06-17', '2015-06-16', '2015-06-15', '2015-06-14',
#        '2015-06-13', '2015-06-12', '2015-06-11', '2015-06-10',
#        '2015-06-09', '2015-06-08', '2015-06-07', '2015-06-06',
#        '2015-06-05', '2015-06-04', '2015-06-03', '2015-06-02',
#        '2015-06-01', '2015-05-31', '2015-05-30', '2015-05-29',
#        '2015-05-28', '2015-05-27', '2015-05-26', '2015-05-25',
#        '2013-05-22', '2013-05-21', '2013-05-20', '2013-05-19',
#        '2013-05-18', '2013-05-17', '2013-05-16', '2013-05-15',
#        '2013-05-14', '2013-05-13', '2013-05-12', '2013-05-11',
#        '2013-05-10', '2013-05-09', '2013-05-08', '2013-05-07',
#        '2013-05-06', '2013-05-05', '2013-05-04', '2013-05-03',
#        '2013-05-02', '2013-05-01', '2013-04-30', '2013-04-29',
#        '2013-04-28', '2013-04-27', '2013-04-26', '2013-04-25',
#        '2013-04-24', '2013-04-23', '2013-04-22', '2013-04-21',
#        '2013-04-20', '2013-04-19', '2013-04-18', '2013-04-17',
#        '2013-04-16', '2013-04-15', '2013-04-14', '2013-04-13',
#        '2013-04-12', '2013-04-11', '2013-04-10', '2013-04-09',
#        '2013-04-08', '2013-04-07', '2013-04-06', '2013-04-05',
#        '2013-04-04', '2013-04-03', '2013-04-02', '2013-04-01',
#        '2013-03-31', '2013-03-30', '2013-03-29', '2013-03-28',
#        '2013-03-27', '2013-03-26', '2013-03-25', '2013-03-24',
#        '2013-03-23', '2013-03-22', '2013-03-21', '2013-03-20',
#        '2013-03-19', '2013-03-18', '2013-03-17', '2013-03-16',
#        '2013-03-15', '2013-03-14', '2013-03-13', '2013-03-12',
#        '2013-03-11', '2013-03-10', '2013-03-09', '2013-03-08',
#        '2013-03-07', '2013-03-06', '2013-03-05', '2013-03-04',
#        '2013-03-03', '2013-03-02', '2013-03-01', '2013-02-28',
#        '2013-02-27', '2013-02-26', '2013-02-25', '2013-02-24',
#        '2013-02-23', '2013-02-22', '2013-02-21', '2013-02-20',
#        '2013-02-19', '2013-02-18', '2013-02-17', '2013-02-16',
#        '2013-02-15', '2013-02-14', '2013-02-13', '2013-02-12',
#        '2013-02-11', '2013-02-10', '2013-02-09', '2013-02-08',
#        '2013-02-07', '2013-02-06', '2013-02-05', '2013-02-04',
#        '2013-02-03', '2013-02-02', '2013-02-01', '2013-01-31',
#        '2013-01-30', '2013-01-29', '2013-01-28', '2013-01-27',
#        '2013-01-26', '2013-01-25', '2013-01-24', '2013-01-23',
#        '2013-01-22', '2013-01-21', '2013-01-20', '2013-01-19',
#        '2013-01-18', '2013-01-17', '2013-01-16', '2013-01-15',
#        '2013-01-14', '2013-01-13', '2013-01-12', '2013-01-11',
#        '2013-01-10', '2013-01-09', '2013-01-08', '2013-01-07',
#        '2013-01-06', '2013-01-05', '2013-01-04', '2013-01-03',
#        '2013-01-02', '2013-01-01'], dtype=object)

# %%
# check the unique data in the following column
cols = ["DayOfWeek", "SchoolHoliday", "StateHoliday", "Open", "Promo"]

for col in cols:
    print(col)
    print(df[col].unique())
    print("-------")
# Out:
# DayOfWeek
# [5 4 3 2 1 7 6]
# -------
# SchoolHoliday
# [1 0]
# -------
# StateHoliday
# ['0' 'a' 'b' 'c' 0]
# -------
# Open
# [1 0]
# -------
# Promo
# [1 0]
# -------

# %%
# check the no of stores in the data
df['Store'].nunique()
# Out:
# 1115

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 62.1+ MB

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
# Store                        1115 non-null int64
# StoreType                    1115 non-null object
# Assortment                   1115 non-null object
# CompetitionDistance          1112 non-null float64
# CompetitionOpenSinceMonth    761 non-null float64
# CompetitionOpenSinceYear     761 non-null float64
# Promo2                       1115 non-null int64
# Promo2SinceWeek              571 non-null float64
# Promo2SinceYear              571 non-null float64
# PromoInterval                571 non-null object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 74.1+ KB

# %% [markdown]
# ## Visualization

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))
sns.countplot(ax=ax1, data=df, hue='DayOfWeek', x='Open')
sns.pointplot(ax=ax2, data=df, hue='DayOfWeek', x='Open')

# %% [markdown]
# ** The chart shows the stores are mainly closed on Sunday

# %%
df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00

# %%
# Extract the year, month and day from the date column

df['Year'] = df.Date.apply(lambda x: x.split("-"))
df['Month'] = df.Year.apply(lambda x: int(x[1]))
df['Day'] = df.Year.apply(lambda x: int(x[2]))
df['Year'] = df.Year.apply(lambda x: int(x[0]))

avgSales = df.groupby('Date')['Sales'].mean()
percentageSale = df.groupby('Date')['Sales'].sum().pct_change()

df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  Day
# 0              1  2015      7   31
# 1              1  2015      7   31
# 2              1  2015      7   31
# 3              1  2015      7   31
# 4              1  2015      7   31

# %%
plt.rcParams['figure.figsize'] = 20,5
sns.factorplot(x="Date", y="Sales", data=df, aspect=3, size=14, kind="point")

# %%
# HeatMap to show correlation between numerical colunms

corr_map = df[df.columns].corr()
obj = np.array(corr_map)
obj[np.tril_indices_from(obj)] = False
fig,ax = plt.subplots()
fig.set_size_inches(10,10)
sns.heatmap(corr_map, mask=obj, square=True, annot=True, vmax=.7)

# %%
def plotter(stringA, stringB):
    fig, ax = plt.subplots(2,1)
    fig.set_size_inches(15,8)
    sns.barplot(x=stringA, y=stringB, data=df, hue='DayOfWeek', ax=ax[0])
    sns.boxplot(x=stringA, y=stringB, data=df, hue='DayOfWeek', ax=ax[1])

# %%
plotter("Year", "Sales")

# %%
plotter("Year", "Customers")

# %%
# Encode StateHoliday
df['StateHoliday'] = df['StateHoliday'].map({0:0, "0":0, "a":1, "b":1, "c":1})
df['StateHoliday'].value_counts()
# Out:
# 0    986159
# 1     31050
# Name: StateHoliday, dtype: int64

# %%
labels = "Affected", "Not Affected"
sizes = df.SchoolHoliday.value_counts()
colors = ["lightblue", "darkgreen"]
explode = (0.1,0.0)
plt.pie(sizes, explode=explode, colors=colors, labels=labels, autopct="%1.1f%%", shadow=True, startangle=180)
plt.axis("equal")
plt.title("Sales Affected by SchoolHoliday or Not")
plt.plot()
fig.set_size_inches(8,8)

# %%
df.Sales.plot(kind='hist', bins=100, xlim=(0,15000))

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
temp = []
for i in df.groupby('Store')[['Sales', 'Customers']].mean()['Sales']:
    temp.append(i)
store['Sales'] = temp

# %%
temp = []
for i in df.groupby('Store')[['Sales', 'Customers']].mean()['Customers']:
    temp.append(i)
store['Customers'] = temp

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval        Sales    Customers
# 0              NaN  3945.704883   467.646497
# 1  Jan,Apr,Jul,Oct  4122.991507   486.045648
# 2  Jan,Apr,Jul,Oct  5741.253715   620.286624
# 3              NaN  8021.769639  1100.057325
# 4              NaN  3867.110403   444.360934

# %%
labels = "a", "b", "c", "d"
sizes = store.StoreType.value_counts()
colors = ["blue", "indigo", "yellow", "pink"]
explode = (0.1, 0.0 , 0.15 , 0.0)
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', explode=explode, shadow=True, startangle=180)
plt.axis('equal')
plt.title("Distribution of different StoreTypes")
plt.gcf()
plt.plot()
fig.set_size_inches = (10,10)

# %%
def plotmaster(StringA , StringB):
  fig, axes = plt.subplots(3,1)
  fig.set_size_inches(12, 15)
  sns.barplot(x=StringA, y=StringB, data=store ,hue="StoreType", ax = axes[0])
  sns.boxplot(x=StringA, y=StringB, data=store ,hue="StoreType", ax=axes[1])
  sns.violinplot(x=StringA, y=StringB, data=store, hue="StoreType" , ax=axes[2])

# %%
plotmaster("Assortment", "Sales")

# %%
plotmaster("Promo2", "Sales")

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# Sales                          0
# Customers                      0
# dtype: int64

# %%
# To get Stores Which are open on Sunday
df[(df['Open'] == 1) & (df['DayOfWeek'] == 7)]['Store'].unique()
# Out:
# array([  85,  122,  209,  259,  262,  274,  299,  310,  335,  353,  423,
#         433,  453,  494,  512,  524,  530,  562,  578,  676,  682,  732,
#         733,  769,  863,  867,  931,  948, 1045, 1081, 1097, 1099,  877],
#       dtype=int64)

# %% [markdown]
# ## Building The Model

# %%
df = df[df["Open"] != 0] # Selecting rows at which store was open
df = df[df["Sales"] > 0] # selecting rows where sales where made
df['log_sales'] = np.log(df['Sales']) # get the log sales to remove skewness (Normalizing) 
df = pd.merge(df, store, on='Store') # Merge storeInfo with the train dataset
df.fillna(0,inplace=True) # replace all missing values with 0

# %%
df = pd.get_dummies(df,columns=['StoreType','Assortment','Year'])

# %%
X = df.drop(['Sales_x','Sales_y','log_sales','Store','Date','Customers_x','Customers_y','CompetitionOpenSinceYear','Promo2SinceYear','PromoInterval'] , axis = 1)
y = df['log_sales']

# %%
X = X.drop('Day', axis=1)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.2, random_state=28)

# %%
# %%time
from sklearn import linear_model
from sklearn import metrics
reg = linear_model.LinearRegression()
reg = reg.fit(X_train, y_train)
y_pred = reg.predict(X_val)
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_pred, y_val)))
# Out:
# RMSE:  0.372513231486058
# Wall time: 2.76 s

# %%
# %%time
tree = DecisionTreeRegressor(max_depth=50,min_samples_split=8)
tree = tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_val)
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_pred_tree, y_val)))
# Out:
# RMSE:  0.15834752799763677
# Wall time: 17 s

# %%
print("MSE: ", metrics.mean_squared_error(y_pred_tree, y_val))
# Out:
# MSE:  0.02507393962296236

# %% [markdown]
# ## Implement Neural Network with BackPropagation using A Multi-layer Perceptron

# %%
# %%time
neural_net = MLPRegressor(early_stopping=True,activation='tanh',hidden_layer_sizes=(10,),verbose=True,solver='adam')
neural_net = neural_net.fit(X_train, y_train)
neural_pred = neural_net.predict(X_val)
print("RMSE: ", np.sqrt(metrics.mean_squared_error(neural_pred, y_val)))
# Out:
# Iteration 1, loss = 2.74202123
# Validation score: 0.001835
# Iteration 2, loss = 0.09029434
# Validation score: 0.002743
# Iteration 3, loss = 0.09023606
# Validation score: 0.003224
# Iteration 4, loss = 0.09021737
# Validation score: 0.003040
# Iteration 5, loss = 0.09018330
# Validation score: 0.002892
# Iteration 6, loss = 0.09019212
# Validation score: -0.000111
# Iteration 7, loss = 0.09019316
# Validation score: 0.003925
# Iteration 8, loss = 0.09018586
# Validation score: 0.000061
# Iteration 9, loss = 0.09017445
# Validation score: 0.003851
# Iteration 10, loss = 0.09017335
# Validation score: 0.003481
# Iteration 11, loss = 0.09017944
# Validation score: 0.002462
# Iteration 12, loss = 0.09017476
# Validation score: 0.002795
# Iteration 13, loss = 0.09018429
# Validation score: 0.003524
# Iteration 14, loss = 0.09017162
# Validation score: 0.003638
# Iteration 15, loss = 0.09016933
# Validation score: 0.003418
# Iteration 16, loss = 0.09018872
# Validation score: 0.004084
# Iteration 17, loss = 0.09017266
# Validation score: 0.000804
# Iteration 18, loss = 0.09017452
# Validation score: 0.004205
# Iteration 19, loss = 0.09018228
# Validation score: 0.003738
# Iteration 20, loss = 0.09018531
# Validation score: 0.004196
# Iteration 21, loss = 0.09017522
# Validation score: 0.004189
# Iteration 22, loss = 0.09016868
# Validation score: 0.003757
# Iteration 23, loss = 0.09018174
# Validation score: 0.003394
# Iteration 24, loss = 0.09018302
# Validation score: 0.003353
# Iteration 25, loss = 0.09018461
# Validation score: -0.000638
# Iteration 26, loss = 0.09016815
# Validation score: 0.003966
# Iteration 27, loss = 0.09017126
# Validation score: 0.003823
# Iteration 28, loss = 0.09017461
# Validation score: 0.003763
# Iteration 29, loss = 0.09017138
# Validation score: 0.003493
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# RMSE:  0.4247967205888798
# Wall time: 1min 59s

# %%
X_train.columns
# Out:
# Index(['DayOfWeek', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 'Month',
#        'Day', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'Promo2',
#        'Promo2SinceWeek', 'StoreType_a', 'StoreType_b', 'StoreType_c',
#        'StoreType_d', 'Assortment_a', 'Assortment_b', 'Assortment_c',
#        'Year_2013', 'Year_2014', 'Year_2015'],
#       dtype='object')

# %% [markdown]
# Neural Network is known to performed even better with a normalized data i.e data with close scale
# StandardScaler() can help do that. it will change the data so that it has a mean of 0 and variance of 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

# %%
# %%time
neural_net = neural_net.fit(X_train, y_train)
neural_pred = neural_net.predict(X_val)
print("RMSE: ", np.sqrt(metrics.mean_squared_error(neural_pred, y_val)))
# Out:
# Iteration 1, loss = 3.40235909
# Validation score: -1.603902
# Iteration 2, loss = 0.15353152
# Validation score: -0.388098
# Iteration 3, loss = 0.09705935
# Validation score: 0.114251
# Iteration 4, loss = 0.07051427
# Validation score: 0.252059
# Iteration 5, loss = 0.06589814
# Validation score: 0.276701
# Iteration 6, loss = 0.06534241
# Validation score: 0.284395
# Iteration 7, loss = 0.06478616
# Validation score: 0.286607
# Iteration 8, loss = 0.06427143
# Validation score: 0.293704
# Iteration 9, loss = 0.06399515
# Validation score: 0.297856
# Iteration 10, loss = 0.06379078
# Validation score: 0.294165
# Iteration 11, loss = 0.06367965
# Validation score: 0.300840
# Iteration 12, loss = 0.06357824
# Validation score: 0.299088
# Iteration 13, loss = 0.06349696
# Validation score: 0.299511
# Iteration 14, loss = 0.06338448
# Validation score: 0.297826
# Iteration 15, loss = 0.06330582
# Validation score: 0.300662
# Iteration 16, loss = 0.06322986
# Validation score: 0.301939
# Iteration 17, loss = 0.06314560
# Validation score: 0.299795
# Iteration 18, loss = 0.06309676
# Validation score: 0.303647
# Iteration 19, loss = 0.06298639
# Validation score: 0.303516
# Iteration 20, loss = 0.06290911
# Validation score: 0.309925
# Iteration 21, loss = 0.06282608
# Validation score: 0.304806
# Iteration 22, loss = 0.06275181
# Validation score: 0.306721
# Iteration 23, loss = 0.06268523
# Validation score: 0.310262
# Iteration 24, loss = 0.06267688
# Validation score: 0.312131
# Iteration 25, loss = 0.06262304
# Validation score: 0.307073
# Iteration 26, loss = 0.06256672
# Validation score: 0.300543
# Iteration 27, loss = 0.06252433
# Validation score: 0.310358
# Iteration 28, loss = 0.06248704
# Validation score: 0.311730
# Iteration 29, loss = 0.06246757
